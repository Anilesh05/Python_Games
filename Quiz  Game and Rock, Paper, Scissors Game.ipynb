# %%
import random                      # Import the random module for generating random choices

def return_play():                #Define a function to again play the game 
    
    #Print the welcome message with emoji and game title
    print("\n\t\t\t\t 👋 𝐇𝐞𝐥𝐥𝐨 𝐄𝐯𝐞𝐫𝐲𝐨𝐧𝐞! 𝐖𝐞𝐥𝐜𝐨𝐦𝐞 𝐭𝐨 𝐦𝐲 𝐆𝐚𝐦𝐞 𝐙𝐨𝐧𝐞")
    
    #Print the game options
    print("\nThere are two Game:-\n\t1. Quiz Game.\n\t2. Rock, Paper, Scissors Game.")

    #Get user input for choosing the game
    game=int(input("\n𝘌𝘯𝘵𝘦𝘳 𝘺𝘰𝘶𝘳 𝘨𝘢𝘮𝘦 1 𝘰𝘳 2 :- "))
 
    if game==1:                         # Check if the chosen game is Quiz (game==1)
    
        def options(a,b,c,d):           # Define a function to display options
            print('\t',a)
            print('\t',b)
            print('\t',c)
            print('\t',d)

        option=["a","b","c","d"]        # Define options for multiple-choice questions
    
        # Print welcome message for the quiz game
        print("\t\t\t\t\t-----𝐖𝐞𝐥𝐜𝐨𝐦𝐞 𝐭𝐨 𝐦𝐲 𝐐𝐮𝐢𝐳 𝐆𝐚𝐦𝐞-----")

        # Print quiz instructions
        print("Instruction:-""\n\t""1. All The MCQ Questions carries 10 marks each"
                          "\n\t""2. Write option! do not write answers"
                           "\n\t""3. There are each set have 10 Question")

        score = 0                          # Initialize the score to zero

        # Ask the user if they are ready to play the quiz
        tell_me=input('\n𝐀𝐫𝐞 𝐲𝐨𝐮 𝐫𝐞𝐚𝐝𝐲 𝐭𝐨 𝐩𝐥𝐚𝐲 𝐭𝐡𝐞 𝐐𝐮𝐢𝐳 ? (𝐲𝐞𝐬/𝐧𝐨) : ')

        if tell_me=='yes':                 # If the user is ready to play
        
            # Display a welcome message for the quiz game
            print('\n\t\t\t\t 𝚆̲𝚎̲𝚕̲𝚌̲𝚘̲𝚖̲𝚎̲ 𝚝̲𝚘̲ 𝚝̲𝚑̲𝚎̲ 𝙶̲𝚎̲𝚗̲𝚎̲𝚛̲𝚊̲𝚝̲𝚎̲ 𝚊̲ 𝚛̲𝚊̲𝚗̲𝚍̲𝚘̲𝚖̲ 𝚀̲𝚞̲𝚒̲𝚣̲ 𝚐̲𝚊̲𝚖̲𝚎̲')
            print('\n\t\t\t\t    𝚋̲𝚊̲𝚜̲𝚎̲𝚍̲ 𝚘̲𝚗̲ 𝚙̲𝚢̲𝚝̲𝚑̲𝚘̲𝚗̲ 𝚙̲𝚛̲𝚘̲𝚐̲𝚛̲𝚊̲𝚖̲𝚖̲𝚒̲𝚗̲𝚐̲ 𝚕̲𝚊̲𝚗̲𝚐̲𝚞̲𝚊̲𝚐̲𝚎̲\n')
    
            for i in range(1,10):           # Iterate through 10 questions 
           
                if i==1:                    # Check the current question number
                    print("1. What is Python?")
                
                    # Display answer options for the question
                    options("a) High-level programming language ","b) Snake species" ,
                        "c) A type of lizard ","d) Both a and b")
            
                    answer=input("\nEnter your option : ")     # Get the user's answer            
               
                    if answer==option[0]:          # Check if the answer is correct and update the score                    
                    
                        score=score+1              # Increment score counter                 
                    
                        print("\tCorrect answer")
                
                    else:                 
                
                        print("\tInCorrect answer")
                    i+=1                           # Increment question counter
                    print("\n------------------------------------------------------------------------------------")
                
                elif i==2:                         # Check if it's the second question
                
                    print("\n 2. Which keyword is used for defining a function in Python?")
                
                    # Display answer options for the question
                    options("a) func","b) define","c) function","d) def")
            
                    answer=input("\nEnter your option : ")          # Get the user's answer 
                
                    if answer==option[3]:          # Check if the answer is correct and update the score
                    
                        score=score+1              # Increment score counter
                    
                        print("\tCorrect answer")
                
                    else:
                        print("\tInCorrect answer")
                    i+=1                            # Increment question counter
                    print("\n------------------------------------------------------------------------------------")
            
                elif i==3:                          # Check if it's the third question
            
                    print("\n 3. What does the range() function in Python do?")
                
                    # Display answer options for the question
                    options("a) Generates a random number ","b) Creates a list of numbers within a specified range",
                            "c) Performs arithmetic operations ","d) Converts a string to a list")
                
                    answer=input("\nEnter your option : ")              # Get the user's answer
                    
                    if answer==option[1]:            # Check if the answer is correct and update the score
                
                        score=score+1                # Increment score counter
                    
                        print("\tCorrect answer")
                
                    else:
                        print("\tInCorrect answer")
                    i+=1                              # Increment question counter
                    print("\n------------------------------------------------------------------------------------")
            
                elif i==4:                            # Check if it's the fourth question
                
                    print("\n 4. Which of the following is used to comment out multiple lines of code in Python?")
                
                    # Display answer options for the question
                    options("a)  // This is a comment ","b)  /* This is a comment */ ",
                            "c)  ''' This is a comment ''' ","d)  # This is a comment")
            
                    answer=input("\nEnter your option : ")# Get the user's answer
                
                    if answer==option[2]:             # Check if the answer is correct and update the score
                    
                        score=score+1                 # Increment score counter
                    
                        print("\tCorrect answer")
                
                    else:
                        print("\tInCorrect answer")
                    i+=1                               # Increment question counter
                    print("\n------------------------------------------------------------------------------------")
            
                elif i==5:                             # Check if it's the fifth question
                
                    print("\n 5. Which statement is used for making decisions in Python?")
                
                    # Display answer options for the question
                    options("a)  for ","b)  while ","c)  if ","d)  switch")
                
                    answer=input("\nEnter your option : ")             # Get the user's answer
                
                    if answer==option[2]:              # Check if the answer is correct and update the score
                    
                        score=score+1                  # Increment score counter
                    
                        print("\tCorrect answer")
                
                    else:
                        print("\tInCorrect answer")
                    i+=1                               # Increment question counter
                    print("\n-------------------------------------------------------------------------------------")
                
                else:                                  # If none of the above conditions are met, exit the loop    
                    break

            j = score*10                               # Calculate the total score in points
        
            q_no=i-1                                   # Determine the total number of questions
        
            percentage=(score*100)/q_no                # Calculate the percentage of correct answers
        
            i = (i-1)*10                               # Convert the question count to a total point scale
        
            print('\n𝐍𝐮𝐦𝐛𝐞𝐫 𝐨𝐟 𝐪𝐮𝐞𝐬𝐭𝐢𝐨𝐧 𝐢𝐬',q_no)        # Display the number of questions attempted
    
            if (j < (i*(40/100))):          # Check the performance and provide feedback based on the score 
                print("𝐎𝐮𝐜𝐡, 𝐲𝐨𝐮𝐫 𝐬𝐜𝐨𝐫𝐞 𝐢𝐬 ",j,"𝐨𝐮𝐭 𝐨𝐟",i," 𝐛𝐞𝐭𝐭𝐞𝐫 𝐥𝐮𝐜𝐤 𝐧𝐞𝐱𝐭 𝐭𝐢𝐦𝐞.")
            
            elif (j >=(i*(40/100))) and (j <= (i*(90/100))):
                print("𝐍𝐢𝐜𝐞! 𝐲𝐨𝐮 𝐬𝐜𝐨𝐫𝐞𝐝 ",j,"𝐨𝐮𝐭 𝐨𝐟",i," 𝐲𝐨𝐮 𝐚𝐫𝐞 𝐪𝐮𝐢𝐞𝐭 𝐬𝐦𝐚𝐫𝐭.")
        
            else:
                print("𝐂𝐨𝐧𝐠𝐫𝐚𝐭𝐮𝐥𝐚𝐭𝐢𝐨𝐧𝐬! 𝐢𝐭'𝐬 𝐚 𝐩𝐞𝐫𝐟𝐞𝐜𝐭 ",j,"𝐨𝐮𝐭 𝐨𝐟",i," 𝐲𝐨𝐮 𝐚𝐫𝐞 𝐈𝐧𝐭𝐞𝐥𝐥𝐢𝐠𝐞𝐧𝐭.")
        
            print(percentage,'% 𝐪𝐮𝐞𝐬𝐭𝐢𝐨𝐧𝐬 𝐚𝐫𝐞 𝐜𝐨𝐫𝐫𝐞𝐜𝐭.')  # Display the percentage of correct answers
            print("\n\t\t----------𝐓𝐡𝐚𝐧𝐤 𝐘𝐨𝐮 𝐭𝐨 𝐩𝐥𝐚𝐲 𝐌𝐲 𝐐𝐮𝐢𝐳 𝐆𝐚𝐦𝐞.----------")     # Display a closing message
    
        else:
             print('\n\t\t----------𝐓𝐡𝐚𝐧𝐤𝐲𝐨𝐮 𝐲𝐨𝐮 𝐚𝐫𝐞 𝐨𝐮𝐭 𝐨𝐟 𝐚 𝐠𝐚𝐦𝐞.----------')     # Display a closing message       
        
        # Ask the user if they want to play other game
        other=input("\n𝐃𝐨 𝐲𝐨𝐮 𝐰𝐚𝐧𝐭 𝐭𝐨 𝐩𝐥𝐚𝐲 𝐨𝐭𝐡𝐞𝐫 𝐠𝐚𝐦𝐞? (𝐲𝐞𝐬/𝐧𝐨): ").lower()
        
        if other=='yes':                             # If the user want to play other, start the game loop
            return_play()                            #start the function
    
    elif game==2:                                     # Check if the user chose the second game
    
        # Display a welcome message for the Rock, Paper, Scissors game
        print("\n\t\t\t\t----𝐖𝐞𝐥𝐜𝐨𝐦𝐞 𝐭𝐨 𝐭𝐡𝐞 𝐑𝐨𝐜𝐤, 𝐏𝐚𝐩𝐞𝐫, 𝐒𝐜𝐢𝐬𝐬𝐨𝐫𝐬 𝐆𝐚𝐦𝐞!----")     
    
        while True:                                  # Game loop for Rock, Paper, Scissors
        
            you = input("\nEnter your choice (🪨rock,📜paper,✂scissors): ").lower() # User input for their choice

            options = ['rock', 'paper', 'scissors']   # List of possible computer choices
        
            computer = random.choice(options)         # Randomly select computer's choice
    
            if you in options:                        # Check if the user's choice is valid
            
                if you == computer:                   # Compare user and computer choices to determine the winner
                      print("\n\tIt's a tie! Both choice are same.")
                elif (
                     (you == 'rock' and computer == 'scissors') or
                     (you == 'paper' and computer == 'rock') or
                     (you == 'scissors' and computer == 'paper')
                     ):
                
                      print("\n\tYou win!",you,"beats",computer,".")
                else:
                     print("\n\tYou lose!",computer,"beats",you,".")         
            else:
                print("\n\tInvalid choice. Please Enter rock, paper, or scissors.")
        
            # Ask the user if they want to play again
            play = input("\n𝐃𝐨 𝐲𝐨𝐮 𝐰𝐚𝐧𝐭 𝐭𝐨 𝐩𝐥𝐚𝐲 𝐚𝐠𝐚𝐢𝐧 𝐭𝐡𝐢𝐬 𝐠𝐚𝐦𝐞? (𝐲𝐞𝐬/𝐧𝐨): ").lower()            
        
            if play != 'yes':                  # If the user doesn't want to play again, exit the game loop

                print("\n\t\t             ----------𝐓𝐡𝐚𝐧𝐤𝐬 𝐟𝐨𝐫 𝐩𝐥𝐚𝐲𝐢𝐧𝐠! 𝐆𝐨𝐨𝐝𝐛𝐲𝐞.---------")
                break

    else:                                       # If the user didn't choose 1 or 2, display an error message
        print("INVALID INPUT!!! Only hit 'yes' or 'no' for your response")

return_play()                                   #start the function
# Out:
# 				 👋 𝐇𝐞𝐥𝐥𝐨 𝐄𝐯𝐞𝐫𝐲𝐨𝐧𝐞! 𝐖𝐞𝐥𝐜𝐨𝐦𝐞 𝐭𝐨 𝐦𝐲 𝐆𝐚𝐦𝐞 𝐙𝐨𝐧𝐞
#
# There are two Game:-
# 	1. Quiz Game.
# 	2. Rock, Paper, Scissors Game.
#
# 𝘌𝘯𝘵𝘦𝘳 𝘺𝘰𝘶𝘳 𝘨𝘢𝘮𝘦 1 𝘰𝘳 2 :- 1
# 					-----𝐖𝐞𝐥𝐜𝐨𝐦𝐞 𝐭𝐨 𝐦𝐲 𝐐𝐮𝐢𝐳 𝐆𝐚𝐦𝐞-----
# Instruction:-
# 	1. All The MCQ Questions carries 10 marks each
# 	2. Write option! do not write answers
# 	3. There are each set have 10 Question
#
# 𝐀𝐫𝐞 𝐲𝐨𝐮 𝐫𝐞𝐚𝐝𝐲 𝐭𝐨 𝐩𝐥𝐚𝐲 𝐭𝐡𝐞 𝐐𝐮𝐢𝐳 ? (𝐲𝐞𝐬/𝐧𝐨) : yes
#
# 				 𝚆̲𝚎̲𝚕̲𝚌̲𝚘̲𝚖̲𝚎̲ 𝚝̲𝚘̲ 𝚝̲𝚑̲𝚎̲ 𝙶̲𝚎̲𝚗̲𝚎̲𝚛̲𝚊̲𝚝̲𝚎̲ 𝚊̲ 𝚛̲𝚊̲𝚗̲𝚍̲𝚘̲𝚖̲ 𝚀̲𝚞̲𝚒̲𝚣̲ 𝚐̲𝚊̲𝚖̲𝚎̲
#
# 				    𝚋̲𝚊̲𝚜̲𝚎̲𝚍̲ 𝚘̲𝚗̲ 𝚙̲𝚢̲𝚝̲𝚑̲𝚘̲𝚗̲ 𝚙̲𝚛̲𝚘̲𝚐̲𝚛̲𝚊̲𝚖̲𝚖̲𝚒̲𝚗̲𝚐̲ 𝚕̲𝚊̲𝚗̲𝚐̲𝚞̲𝚊̲𝚐̲𝚎̲
#
# 1. What is Python?
# 	 a) High-level programming language
# 	 b) Snake species
# 	 c) A type of lizard
# 	 d) Both a and b
#
# Enter your option : a
# 	Correct answer
#
# ------------------------------------------------------------------------------------
#
#  2. Which keyword is used for defining a function in Python?
# 	 a) func
# 	 b) define
# 	 c) function
# 	 d) def
#
# Enter your option : d
# 	Correct answer
#
# ...
